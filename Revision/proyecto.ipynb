# %%
import pandas as pd

from google.colab import drive
drive.mount("/content/drive/")

datos = pd.read_excel("/content/drive/MyDrive/BASES/datos.xlsx")
datos = datos.drop(columns=['Mes', 'Año', 'IMAE_ULT_12M'])
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#     Mes   Año  RESERVA NETA  RESERVA NETA REAL         IPC  IPC VAR MENSUAL  \
# 0     1  2018        7120.1        7184.838392   96.078188         0.406470
# 1     2  2018        7015.9        6556.146649   96.280664         0.210741
# 2     3  2018        8473.9        8051.096877   96.250528        -0.031300
# 3     4  2018        8128.2        7645.799703   96.174542        -0.078947
# 4     5  2018        8010.7        6880.991513   96.067465        -0.111336
# 5     6  2018        8070.9        8297.460834   96.237918         0.177431
# 6     7  2018        7900.4        7807.519166   96.503438         0.275900
# 7     8  2018        7800.0        7380.239166   96.439755        -0.065991
# 8     9  2018        7468.8        8085.051738   96.653069         0.221189
# 9    10  2018        6866.2        8074.989289   97.014241         0.373679
# ...

# %%
import pandas as pd
import openpyxl

matriz_cor = datos.corr()
matriz_cor = pd.DataFrame(matriz_cor)

matriz_cor

matriz_cor.to_excel("matriz.xlsx", index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Graficar la matriz de correlación
sns.heatmap(matriz_cor, cmap='coolwarm', annot=True)
plt.show()
