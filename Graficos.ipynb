# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
import matplotlib.dates as mdates

# %%
datos = pd.read_excel('datos.xlsx')

# %%
meses = {'Enero':1, 'Febrero':2, 'Marzo':3, 'Abril':4, 'Mayo':5, 'Junio':6, 'Julio':7, 'Agosto':8, 'Septiembre':9, 'Octubre':10, 'Noviembre':11, 'Diciembre':12}

# %%
datos['Mes'] = datos['Mes'].map(meses)

# %%
datos = datos.rename(columns={'Mes': 'month', 'Año':'year'})

# %%
datos['fecha'] = pd.to_datetime(datos[['year', 'month']].assign(Day=1))

# %%
sns.lineplot(x=datos['fecha'], y=datos['Reserva_Neta'], label='Reserva Neta')
sns.lineplot(x=datos['fecha'], y=datos['Reserva_Neta_Real'], label='Reserva Neta Real')
plt.xlabel('Fecha')
plt.ylabel('Reserva en millones de colones')
plt.title('Comparación Reserva Neta vrs Reserva Neta Real en el periodo del 2018 al 2022')
plt.xticks(rotation=45)
# Out:
# (array([17532., 17713., 17897., 18078., 18262., 18444., 18628., 18809.,
#         18993.]),
#  [Text(17532.0, 0, '2018-01'),
#   Text(17713.0, 0, '2018-07'),
#   Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01')])

# %%
sns.lineplot(x=datos['fecha'], y=datos['TC_DOLAR'], label='Tipo de cambio colones por dolar')
plt.xlabel('Fecha')
plt.ylabel('Colones por un dolar')
plt.title('Tipo de cambio colones por dolar en el periodo del 2018 al 2022')
plt.xticks(rotation=45)
# Out:
# (array([17532., 17713., 17897., 18078., 18262., 18444., 18628., 18809.,
#         18993.]),
#  [Text(17532.0, 0, '2018-01'),
#   Text(17713.0, 0, '2018-07'),
#   Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01')])

# %%
datos.columns
# Out:
# Index(['month', 'year', 'Reserva_Neta', 'Reserva_Neta_Real', 'IPC_Nivel',
#        'IPC_VAR_MENSUAL', 'IMAE_ULT_12M', 'TC_DOLAR', 'fecha'],
#       dtype='object')

# %%
sns.lineplot(x=datos['fecha'], y=datos['IPC_Nivel'])
plt.xlabel('Fecha')
plt.ylabel('IPC')
plt.title('Índice de precios al consumidor en el periodo del 2018 al 2022')
plt.xticks(rotation=45)
# Out:
# (array([17532., 17713., 17897., 18078., 18262., 18444., 18628., 18809.,
#         18993.]),
#  [Text(17532.0, 0, '2018-01'),
#   Text(17713.0, 0, '2018-07'),
#   Text(17897.0, 0, '2019-01'),
#   Text(18078.0, 0, '2019-07'),
#   Text(18262.0, 0, '2020-01'),
#   Text(18444.0, 0, '2020-07'),
#   Text(18628.0, 0, '2021-01'),
#   Text(18809.0, 0, '2021-07'),
#   Text(18993.0, 0, '2022-01')])
